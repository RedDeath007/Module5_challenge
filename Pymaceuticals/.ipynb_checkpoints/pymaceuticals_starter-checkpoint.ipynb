# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
#added linregress for final graph
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
test_results = pd.merge(study_results, mouse_metadata, 
                        how="left", on="Mouse ID")

# Display the data table for preview
test_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
total_mice = len(test_results["Mouse ID"].unique())
total_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_id = test_results.loc[test_results.duplicated(subset=['Mouse ID', 'Timepoint']),'Mouse ID'].unique()
duplicate_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_df = test_results.loc[test_results["Mouse ID"] == "g989", :]
duplicate_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
reduced_df = test_results[test_results["Mouse ID"].isin(duplicate_id) == False]
reduced_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
reduced_total = len(reduced_df["Mouse ID"].unique())
reduced_total
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean = reduced_df["Tumor Volume (mm3)"].groupby(reduced_df['Drug Regimen']).mean()
median = reduced_df["Tumor Volume (mm3)"].groupby(reduced_df['Drug Regimen']).median()
var = reduced_df["Tumor Volume (mm3)"].groupby(reduced_df['Drug Regimen']).var()
stdev = reduced_df["Tumor Volume (mm3)"].groupby(reduced_df['Drug Regimen']).std()
sem = reduced_df["Tumor Volume (mm3)"].groupby(reduced_df['Drug Regimen']).sem()

# Assemble the resulting series into a single summary DataFrame.
summary_df = pd.DataFrame({"Mean Tumor Volume": mean,
                          "Median Tumor Volume": median,
                          "Tumor Volume Variance": var,
                          "Tumor Volume Standard Dev.": stdev,
                          "Tumor Volume Standard Error": sem})
summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Dev.  Tumor Volume Standard Error
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
agg_df = reduced_df.groupby('Drug Regimen').agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"]})
agg_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
mice_per_regimen = reduced_df.groupby('Drug Regimen').count()['Mouse ID']
pandas_plot = mice_per_regimen.plot(kind= "bar", color= "blue")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.title("Pandas Plot")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
x_value = mice_per_regimen.index
y_value = mice_per_regimen.values
plt.bar(x_value, y_value, color= "blue")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.title("PyPlot")
plt.xticks(rotation= "vertical")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_gender = reduced_df['Sex'].value_counts()
pandas_pie = mice_gender.plot(kind= "pie", autopct= '%1.1f%%')
plt.title("Male vs Female Mice distribution Pandas Pie")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(mice_gender,labels = mice_gender.index, autopct= '%1.1f%%')
plt.title("Male vs Female Mice distribution Pyplot Pie")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse
#getting last point for each mouse ID
last_timepoint = reduced_df.groupby(["Mouse ID"])["Timepoint"].max()
last_timepoint = last_timepoint.reset_index()


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
#merging the timepoint and reduced data
timepoint_merge_df = last_timepoint.merge(reduced_df, on=["Mouse ID", "Timepoint"], how="left")
timepoint_merge_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 2     a262         45           70.717621                 4      Placebo
# 3     a275         45           62.999356                 3     Ceftamin
# 4     a366         30           63.440686                 1     Stelasyn
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female          17          29
# 3  Female          20          28
# 4  Female          16          29

# %%
# Put treatments into a list for for loop (and later for plot labels)
drugs = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_list= []

# Locate the rows which contain mice on each drug and get the tumor volumes
for drug in drugs:
    
    drug_series = timepoint_merge_df.loc[timepoint_merge_df["Drug Regimen"] == drug,"Tumor Volume (mm3)"]
    
    # add subset 
    #adding to the volume list
    
    tumor_volume_list.append(drug_series)
    
    # Calculate the IQR and quantitatively determine if there are any potential outliers. 

    quartiles = drug_series.quantile([.25, .5, .75])
    lower_q = quartiles[.25]
    upper_q = quartiles[.75]
    iqr = upper_q - lower_q
    # Determine outliers using upper and lower bounds    
    lower_bound = lower_q - (1.5*iqr)
    upper_bound = upper_q + (1.5*iqr)
    
    outliers = drug_series.loc[(drug_series < lower_bound) | (drug_series > upper_bound)]
    
    print(f"{drug}\'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(tumor_volume_list, labels = drugs)
plt.ylabel("Final Tumor Volume(mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
#make drug dataframe
capomulin_df = reduced_df.loc[reduced_df['Drug Regimen']== "Capomulin", :]

#get data for mouse l509 similar to example graph
mouse_in_capomulin = capomulin_df.loc[capomulin_df["Mouse ID"] == "l509",:]

#build plot code
x_value = mouse_in_capomulin["Timepoint"]
volume = mouse_in_capomulin["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()
plt.plot(x_value, volume, color= "blue")
plt.title("Capomulin treatment of Mouse l509")
plt.xlabel("timepoint(days)")
plt.ylabel("Tumor Volume(mm3)")
plt.show()

capomulin_df.head()
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128          0                45.0                 0    Capomulin
# 226     j246          0                45.0                 0    Capomulin
# 227     r554          0                45.0                 0    Capomulin
# 228     s185          0                45.0                 0    Capomulin
# 229     b742          0                45.0                 0    Capomulin
#
#         Sex  Age_months  Weight (g)
# 0    Female           9          22
# 226  Female          21          21
# 227  Female           8          17
# 228  Female           3          17
# 229    Male           7          21

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

#remake capomulin DF
capomulin_df = reduced_df.loc[reduced_df['Drug Regimen']== "Capomulin", :]

avg_capomulin_df = capomulin_df.groupby(['Mouse ID'])[['Weight (g)', 'Tumor Volume (mm3)']].mean()

fig1, ax1 = plt.subplots()
plt.scatter(avg_capomulin_df['Weight (g)'],avg_capomulin_df['Tumor Volume (mm3)'], marker = 'o', color = 'blue')
plt.title("Scatter Plot of Capomulin Treated Mice")
plt.xlabel("Weight(g)")
plt.ylabel("Avg Tumor Volume(mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
corr = round(st.pearsonr(avg_capomulin_df["Weight (g)"],avg_capomulin_df["Tumor Volume (mm3)"])[0],3)
print(f'The correlation between mouse weight and avg tumor volume is {corr}')

x_values = avg_capomulin_df["Weight (g)"]
y_values = avg_capomulin_df["Tumor Volume (mm3)"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regression = x_values * slope + intercept
linear_regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

fig1, ax1 = plt.subplots()
plt.scatter(x_values,y_values,color = "blue")
plt.plot(x_values,regression,"r-")
plt.title("linear regression plot for mouse weight vs avg tumor volume")
plt.xlabel("Weight(g)")
plt.ylabel("Avg Tumor Volume(mm3)")
plt.show()
# Out:
# The correlation between mouse weight and avg tumor volume is 0.842
